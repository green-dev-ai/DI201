# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sts

temps = np.random.uniform(-5, 35, 120)
# temps - reshape
data = {
    'Average Tempratures': [temps],
    'Cities': ['New York', 'Boston', 'Los Angeles', 'San Diego', 'Chicago', 'Denver', 'Miami', 'Atlanta', 'Seatle', 'Detroit'],
}

df = pd.DataFrame(data)

print(df)



# 10 cities - 12 months

# sec2

# min max

# sec 3

# visualization

# summary report
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 13
#       9     'Average Tempratures': [temps],
#      10     'Cities': ['New York', 'Boston', 'Los Angeles', 'San Diego', 'Chicago', 'Denver', 'Miami', 'Atlanta', 'Seatle', 'Detroit'],
#      11 }
#      12
# ---> 13 df = pd.DataFrame(data)
#      14
#      15 print(df)
#      16
#
# File c:\Users\Joseph\OneDrive - ISC\Desktop\Private\AI for Law Office\Developers Institute\vs studio\.venv\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
# ...
